# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1. Import the data sets

# %%
path = r'C:\Users\julia\anaconda3\Instacart Basket Analysis'

# %%
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_new.pkl'))

# %%
df = df_ords_prods_merged[:1000000]

# %% [markdown]
# ## 2. Check data frame

# %%
df.shape
# Out:
# (3806, 21)

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                             product_name  aisle_id  \
# 0          24          25  Salted Caramel Lean Protein & Fiber Bar         3
# 1          33          34                                      NaN       121
# 2          44          45                        European Cucumber        83
# 3          44          45                        European Cucumber        83
# 4          44          45                        European Cucumber        83
#
#    department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0             19     1.9      2510     4297    prior            10  ...
# 1             14    12.2     10142     4604    prior             5  ...
# 2              4    14.3      1425     2593    prior             4  ...
# 3              4    14.3      1915     4631    prior            29  ...
# 4              4    14.3      1375     5801    prior            16  ...
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                 12                     6.0                 18          1
# 1                 12                     8.0                  7          1
# 2                 14                     7.0                  7          1
# 3                 20                     7.0                  5          1
# 4                 17                     6.0                 10          0
#
#    _merge        price_range    price_range_loc     busiest_day  \
# 0    both  Low-range product  Low-range product      Least busy
# 1    both  Mid-range product  Mid-range product  Regularly busy
# 2    both  Mid-range product  Mid-range product  Regularly busy
# 3    both  Mid-range product  Mid-range product  Regularly busy
# 4    both  Mid-range product  Mid-range product  Regularly busy
#
#      busiest_days busiest_period_of_day
# 0    Slowest days           Most orders
# 1    Busiest days           Most orders
# 2    Busiest days           Most orders
# 3  Regularly busy        Average orders
# 4    Busiest days        Average orders
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 3. Test the groupby function

# %%
# Splitting the data into groups
df.groupby('product_name')

# %%
# Apply the agg() function 
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.715556
# 2                17.750000
# 3                16.360000
# 4                17.860915
# 5                 9.555556
# 6                16.512195
# 7                20.100559
# 8                16.700000
# 9                15.864583
# 10               25.000000
# 11               20.841270
# 12               15.974359
# 13               15.824885
# 14               25.406593
# 15               19.086957
# 16               18.051458
# 17               16.927083
# 18               25.804878
# 19               19.769697
# 20               22.085271
# 21               30.333333

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.715556   1  84
# 2                17.750000   5  31
# 3                16.360000   1  84
# 4                17.860915   1  84
# 5                 9.555556   1  28
# 6                16.512195   1  54
# 7                20.100559   1  92
# 8                16.700000   1  60
# 9                15.864583   1  61
# 10               25.000000   2  68
# 11               20.841270   1  68
# 12               15.974359   1  84
# 13               15.824885   1  66
# 14               25.406593   1  82
# 15               19.086957   1  65
# 16               18.051458   1  82
# 17               16.927083   1  59
# 18               25.804878   1  63
# 19               19.769697   1  92
# 20               22.085271   1  84
# 21               30.333333   2  61

# %%
# Aggregating Data with transform
df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_38624\3131866696.py:2: FutureWarning: The provided callable <function max at 0x00000233B4065440> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                             product_name  aisle_id  \
# 0          24          25  Salted Caramel Lean Protein & Fiber Bar         3
# 1          33          34                                      NaN       121
# 2          44          45                        European Cucumber        83
# 3          44          45                        European Cucumber        83
# 4          44          45                        European Cucumber        83
#
#    department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0             19     1.9      2510     4297    prior            10  ...
# 1             14    12.2     10142     4604    prior             5  ...
# 2              4    14.3      1425     2593    prior             4  ...
# 3              4    14.3      1915     4631    prior            29  ...
# 4              4    14.3      1375     5801    prior            16  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  \
# 0                     6.0                 18          1    both
# 1                     8.0                  7          1    both
# 2                     7.0                  7          1    both
# 3                     7.0                  5          1    both
# 4                     6.0                 10          0    both
#
#          price_range    price_range_loc     busiest_day    busiest_days  \
# 0  Low-range product  Low-range product      Least busy    Slowest days
# 1  Mid-range product  Mid-range product  Regularly busy    Busiest days
# 2  Mid-range product  Mid-range product  Regularly busy    Busiest days
# 3  Mid-range product  Mid-range product  Regularly busy  Regularly busy
# 4  Mid-range product  Mid-range product  Regularly busy    Busiest days
#
#   busiest_period_of_day max_order
# 0           Most orders        10
# 1           Most orders         5
# 2           Most orders         4
# 3        Average orders        29
# 4        Average orders        16
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 3. Creating a loyalty flag for existing customers

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['max_order'] <= 40) & (df_ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# New customer        1673
# Regular customer    1618
# Loyal customer       515
# Name: count, dtype: int64

# %%
df_ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0      4297      New customer            10
# 1      4604      New customer             5
# 2      2593      New customer             4
# 3      4631  Regular customer            29
# 4      5801  Regular customer            16
# 5      6778  Regular customer            15
# 6      4297      New customer            10
# 7       999  Regular customer            27
# 8      6141  Regular customer            16
# 9      3051      New customer             2
# 10     1072      New customer             7
# 11     3412    Loyal customer            48
# 12     1815  Regular customer            24
# 13     3964    Loyal customer            47
# 14     4067    Loyal customer            61
# 15     5575      New customer             2
# 16     2985  Regular customer            11
# 17     6801    Loyal customer            59
# 18     5642  Regular customer            15
# 19     4313      New customer             6
# 20     4631  Regular customer            29
# 21     5321  Regular customer            12
# 22     4631  Regular customer            29
# 23     6754  Regular customer             2
# 24     6754  Regular customer            27
# 25     4900      New customer             8
# 26      222    Loyal customer            68
# 27      653  Regular customer            19
# 28     1059  Regular customer            27
# 29     1423      New customer             7
# 30     1642  Regular customer            16
# 31     4326  Regular customer            11
# 32     4520      New customer             9
# 33     6126      New customer             8
# 34     6851  Regular customer            26
# 35     6060  Regular customer            24
# 36     5543      New customer             3
# 37     5255      New customer             2
# 38     1955  Regular customer            29
# 39     5543      New customer             3
# 40     4111      New customer             9
# 41     3459      New customer             2
# 42     6735  Regular customer            12
# 43     2335  Regular customer            31
# 44      150  Regular customer            27
# 45     5152      New customer             2
# 46      857  Regular customer            34
# 47     1378  Regular customer            34
# 48     6141  Regular customer             1
# 49     3273  Regular customer            26
# 50     6517      New customer             3
# 51     4057      New customer             1
# 52     4076  Regular customer            30
# 53     1710      New customer             1
# 54     3422  Regular customer            25
# 55     2868  Regular customer            26
# 56     5927  Regular customer            14
# 57     4993  Regular customer            14
# 58     2011  Regular customer            19
# 59     2022  Regular customer            13

# %% [markdown]
# ## 4. Find the mean for the entire data frame

# %%
df_ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.715556
# 2                17.750000
# 3                16.360000
# 4                17.860915
# 5                 9.555556
# 6                16.512195
# 7                20.100559
# 8                16.700000
# 9                15.864583
# 10               25.000000
# 11               20.841270
# 12               15.974359
# 13               15.824885
# 14               25.406593
# 15               19.086957
# 16               18.051458
# 17               16.927083
# 18               25.804878
# 19               19.769697
# 20               22.085271
# 21               30.333333

# %%
# When looking at the mean for the entire data frame rather than a subset we can see that the order numbers are higher for each department.

# %% [markdown]
# ## 5. Checking the basic statistics of the product prices for each loyalty category

# %%
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer     7.137476  1.1     23.2
# New customer       7.860012  1.0     25.0
# Regular customer  17.077565  1.0  14900.0

# %%
# Loyal and new customers spend about the same average amount. Only the regular customers spend around 10$ more than that.

# %% [markdown]
# ## 6. Targeting different types of spenders in their marketing campaigns

# %%
df_ords_prods_merged['mean_product_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_38624\2682762691.py:1: FutureWarning: The provided callable <function mean at 0x00000233B4065E40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_ords_prods_merged['mean_product_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merged[['user_id', 'mean_product_price']].head(20)
# Out:
#     user_id  mean_product_price
# 0      4297            5.476923
# 1      4604            8.247368
# 2      2593            7.332143
# 3      4631            8.776471
# 4      5801            7.666667
# 5      6778            9.133333
# 6      4297            5.476923
# 7       999            8.840000
# 8      6141            9.776667
# 9      3051            7.635294
# 10     1072            8.053846
# 11     3412            4.383333
# 12     1815            6.781250
# 13     3964            8.169565
# 14     4067            9.114286
# 15     5575            9.090000
# 16     2985            5.300000
# 17     6801            7.205882
# 18     5642            6.120000
# 19     4313            9.100000

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['mean_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['mean_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_merged['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     3642
# High spender     164
# Name: count, dtype: int64

# %%
df_ords_prods_merged[['user_id', 'mean_product_price', 'spending_flag']].head(20)
# Out:
#     user_id  mean_product_price spending_flag
# 0      4297            5.476923   Low spender
# 1      4604            8.247368   Low spender
# 2      2593            7.332143   Low spender
# 3      4631            8.776471   Low spender
# 4      5801            7.666667   Low spender
# 5      6778            9.133333   Low spender
# 6      4297            5.476923   Low spender
# 7       999            8.840000   Low spender
# 8      6141            9.776667   Low spender
# 9      3051            7.635294   Low spender
# 10     1072            8.053846   Low spender
# 11     3412            4.383333   Low spender
# 12     1815            6.781250   Low spender
# 13     3964            8.169565   Low spender
# 14     4067            9.114286   Low spender
# 15     5575            9.090000   Low spender
# 16     2985            5.300000   Low spender
# 17     6801            7.205882   Low spender
# 18     5642            6.120000   Low spender
# 19     4313            9.100000   Low spender

# %%
## 7.

# %%
df_ords_prods_merged['median_days_between_orders'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_38624\1068800140.py:1: FutureWarning: The provided callable <function median at 0x00000233B41A5D00> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_ords_prods_merged['median_days_between_orders'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merged[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(20)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0      4297                     6.0                         6.0
# 1      4604                     8.0                         8.0
# 2      2593                     7.0                         7.0
# 3      4631                     7.0                         7.0
# 4      5801                     6.0                         6.0
# 5      6778                     8.0                         8.0
# 6      4297                     6.0                         6.0
# 7       999                    13.0                        13.0
# 8      6141                     0.0                         0.0
# 9      3051                    30.0                        30.0
# 10     1072                     4.0                         4.0
# 11     3412                     7.0                         7.0
# 12     1815                     7.0                         7.0
# 13     3964                     6.0                         6.0
# 14     4067                     1.0                         1.0
# 15     5575                    27.0                        27.0
# 16     2985                    17.0                        17.0
# 17     6801                     7.0                         5.0
# 18     5642                     7.0                         7.0
# 19     4313                     8.0                         8.0

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_between_orders'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['median_days_between_orders'] <= 20) & (df_ords_prods_merged['median_days_between_orders'] > 10), 'order_frequency'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_between_orders'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
df_ords_prods_merged['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer        2220
# Non-frequent customer     702
# Regular customer          667
# nan                       217
# Name: count, dtype: int64

# %%
df_ords_prods_merged[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency']].head(20)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0      4297                     6.0                         6.0
# 1      4604                     8.0                         8.0
# 2      2593                     7.0                         7.0
# 3      4631                     7.0                         7.0
# 4      5801                     6.0                         6.0
# 5      6778                     8.0                         8.0
# 6      4297                     6.0                         6.0
# 7       999                    13.0                        13.0
# 8      6141                     0.0                         0.0
# 9      3051                    30.0                        30.0
# 10     1072                     4.0                         4.0
# 11     3412                     7.0                         7.0
# 12     1815                     7.0                         7.0
# 13     3964                     6.0                         6.0
# 14     4067                     1.0                         1.0
# 15     5575                    27.0                        27.0
# 16     2985                    17.0                        17.0
# 17     6801                     7.0                         5.0
# 18     5642                     7.0                         7.0
# 19     4313                     8.0                         8.0
#
#           order_frequency
# 0       Frequent customer
# 1       Frequent customer
# 2       Frequent customer
# 3       Frequent customer
# 4       Frequent customer
# 5       Frequent customer
# 6       Frequent customer
# 7        Regular customer
# 8       Frequent customer
# 9   Non-frequent customer
# 10      Frequent customer
# 11      Frequent customer
# 12      Frequent customer
# 13      Frequent customer
# 14      Frequent customer
# 15  Non-frequent customer
# 16       Regular customer
# 17      Frequent customer
# 18      Frequent customer
# 19      Frequent customer

# %% [markdown]
# ## 7. Exporting data frame

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged_grouped.pkl'))
