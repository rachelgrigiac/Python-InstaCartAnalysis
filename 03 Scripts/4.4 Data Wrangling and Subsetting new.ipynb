# %%
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# Importing Data Sets

# %%
df_ords = pd.read_csv(r'C:\Users\julia\anaconda3\Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)

# %%
df_prods = pd.read_csv(r'C:\Users\julia\anaconda3\Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
df_dep = pd.read_csv(r'C:\Users\julia\anaconda3\Instacart Basket Analysis\02 Data\Original Data\departments.csv', index_col = False)

# %%
path = r'C:\Users\julia\anaconda3\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\julia\\anaconda3\\Instacart Basket Analysis'

# %%
# ! I want to use the path join function, so I can export the data in the last step but I don't find my mistake !

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Excluding columns we don't need

# %%
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Task 2 - Changing the data type of another unnecessary column

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords = df_ords.drop(columns = ['order_id'])

# %%
# Task 3 - Change the name of order_dow

# %%
df_ords.head()
# Out:
#    user_id  order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0        1             1          2                  8                     NaN
# 1        1             2          3                  7                    15.0
# 2        1             3          3                 12                    21.0
# 3        1             4          4                  7                    29.0
# 4        1             5          4                 15                    28.0

# %%
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0        1             1                  2                  8
# 1        1             2                  3                  7
# 2        1             3                  3                 12
# 3        1             4                  4                  7
# 4        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Task 4 -  What the busiest hour is for placing orders?

# %%
df_ords.describe()
# Out:
#             user_id  order_number  order_day_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06       3.421083e+06       3.421083e+06
# mean   1.029782e+05  1.715486e+01       2.776219e+00       1.345202e+01
# std    5.953372e+04  1.773316e+01       2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00       0.000000e+00       0.000000e+00
# 25%    5.139400e+04  5.000000e+00       1.000000e+00       1.000000e+01
# 50%    1.026890e+05  1.100000e+01       3.000000e+00       1.300000e+01
# 75%    1.543850e+05  2.300000e+01       5.000000e+00       1.600000e+01
# max    2.062090e+05  1.000000e+02       6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
## The busiest hour of the day is 1 (mean = 1.345202e+01)

# %%
# Task 5 - Determine the meaning behind a value of 4 in the "department_id" column

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
df_dep_t_new.head()
# Out:
# department_id department
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# Task 6 - Create a subset about breakfast item sales

# %%
df_breakfast =  df_prods[df_prods['department_id']==3]

# %%
df_breakfast
# Out:
#        product_id                   product_name  aisle_id  department_id  \
# 57             58          Whole Wheat Tortillas       128              3
# 82             83    100% Whole Wheat Pita Bread       128              3
# 100           101     Bread, Healthy Whole Grain       112              3
# 107           108  Organic Sprouted Barley Bread       112              3
# 115           116                            NaN        93              3
# ...           ...                            ...       ...            ...
# 49513       49509  Gluten Free Classic Sourdough       112              3
# 49625       49621                  Challah Bread       112              3
# 49644       49640                 Sourdough Loaf       112              3
# 49660       49656     Masada Kosher Pocket Bread       128              3
# 49690       49686               Artisan Baguette       112              3
#
#        prices
# 57        6.7
# 82       14.4
# 100       5.2
# 107      14.4
# ...

# %%
# Task 7 - Dinner Parties

# %%
df_dinner_parties = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinner_parties
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# Task 8 - How many rows does the last data frame has?

# %%
df_dinner_parties.shape
# Out:
# (7650, 5)

# %%
# Task 9 - Info about user_id = 1

# %%
user_1_info = df_ords[df_ords['user_id'] == 1]

# %%
user_1_info
# Out:
#     user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0         1             1                  2                  8
# 1         1             2                  3                  7
# 2         1             3                  3                 12
# 3         1             4                  4                  7
# 4         1             5                  4                 15
# 5         1             6                  2                  7
# 6         1             7                  1                  9
# 7         1             8                  1                 14
# 8         1             9                  1                 16
# 9         1            10                  4                  8
# 10        1            11                  4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# ...

# %%
# Task 10 - Details about this user’s behavior

# %%
user_1_info.describe()
# Out:
#        user_id  order_number  order_day_of_week  order_hour_of_day  \
# count     11.0     11.000000          11.000000          11.000000
# mean       1.0      6.000000           2.636364          10.090909
# std        0.0      3.316625           1.286291           3.477198
# min        1.0      1.000000           1.000000           7.000000
# 25%        1.0      3.500000           1.500000           7.500000
# 50%        1.0      6.000000           3.000000           8.000000
# 75%        1.0      8.500000           4.000000          13.000000
# max        1.0     11.000000           4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# Export orders data frame

# %%
df_ords.to_csv(r'C:\Users\julia\anaconda3\Instacart Basket Analysis\02 Data\Prepared Data', 'orders_wrangled.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df_ords.to_csv(r'C:\Users\julia\anaconda3\Instacart Basket Analysis\02 Data\Prepared Data', 'orders_wrangled.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
# ...

# %%
# Somehow I managed to export it bu now I'm not sure how I did it anymore :)
