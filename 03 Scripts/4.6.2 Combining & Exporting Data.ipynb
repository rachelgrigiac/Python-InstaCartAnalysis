# %% [markdown]
# # 4.6.2 Combining & Exporting Data

# %% [markdown]
# ## This script contains the following points:

# %% [markdown]
# ### 1. Import the data sets

# %% [markdown]
# ### 2. Check the dimensions of the imported dataframes

# %% [markdown]
# ### 3. Determine a suitable way to combine the dataframes

# %% [markdown]
# ### 4. Confirm the results of the merge using the merge flag

# %% [markdown]
# ### 5. Export the newly created dataframe in a suitable format

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 1. Import the data sets

# %%
path = r'C:\Users\julia\anaconda3\Instacart Basket Analysis'

# %%
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %% [markdown]
# ### 2. Check the dimensions of the imported dataframes

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0      8382       23    prior             2          0                 10
# 1      8382       23    prior             2          0                 10
# 2      8382       23    prior             2          0                 10
# 3      8382       23    prior             2          0                 10
# 4      8382       23    prior             2          0                 10
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     9.0        3873                  1          0   both
# 1                     9.0       28199                  2          0   both
# 2                     9.0       42372                  3          0   both
# 3                     9.0       23106                  4          0   both
# 4                     9.0       33819                  5          0   both

# %%
df_ords_prods_combined.shape
# Out:
# (3809, 11)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.shape
# Out:
# (49693, 6)

# %% [markdown]
# ### 3. Determine a suitable way to combine the dataframes

# %%
df_ords_prods_merged = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_ords_prods_merged = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10487, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10468 @Substitution("")
#   10469 @Appender(_merge_doc, indents=2)
#   10470 def merge(
#    (...)
#   10483     validate: MergeValidate | None = None,
#   10484 ) -> DataFrame:
#   10485     from pandas.core.reshape.merge import merge
# > 10487     return merge(
#   10488         self,
#   10489         right,
#   10490         how=how,
#   10491         on=on,
#   10492         left_on=left_on,
#   10493         right_on=right_on,
#   10494         left_index=left_index,
#   10495         right_index=right_index,
#   10496         sort=sort,
#   10497         suffixes=suffixes,
#   10498         copy=copy,
#   10499         indicator=indicator,
#   10500         validate=validate,
#   10501     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:881, in _MergeOperation.get_result(self, copy)
#     879 def get_result(self, copy: bool | None = True) -> DataFrame:
#     880     if self.indicator:
# --> 881         self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     883     join_index, left_indexer, right_indexer = self._get_join_info()
#     885     result = self._reindex_and_concat(
#     886         join_index, left_indexer, right_indexer, copy=copy
#     887     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:924, in _MergeOperation._indicator_pre_merge(self, left, right)
#     919         raise ValueError(
#     920             "Cannot use `indicator=True` option when "
#     921             f"data contains a column named {i}"
#     922         )
#     923 if self._indicator_name in columns:
# --> 924     raise ValueError(
#     925         "Cannot use name of an existing column for indicator column"
#     926     )
#     928 left = left.copy()
#     929 right = right.copy()
#
# ValueError: Cannot use name of an existing column for indicator column

# %%
# Because merge already exists in the dataframe, I have to drop it first

# %%
df_ords_prods_combined = df_ords_prods_combined.drop(['_merge'], axis=1)

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0      8382       23    prior             2          0                 10
# 1      8382       23    prior             2          0                 10
# 2      8382       23    prior             2          0                 10
# 3      8382       23    prior             2          0                 10
# 4      8382       23    prior             2          0                 10
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     9.0        3873                  1          0
# 1                     9.0       28199                  2          0
# 2                     9.0       42372                  3          0
# 3                     9.0       23106                  4          0
# 4                     9.0       33819                  5          0

# %%
df_ords_prods_merged = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged
# Out:
#       Unnamed: 0  product_id                             product_name  \
# 0             24          25  Salted Caramel Lean Protein & Fiber Bar
# 1             33          34                                      NaN
# 2             44          45                        European Cucumber
# 3             44          45                        European Cucumber
# 4             44          45                        European Cucumber
# ...          ...         ...                                      ...
# 3801       49687       49683                           Cucumber Kirby
# 3802       49687       49683                           Cucumber Kirby
# 3803       49687       49683                           Cucumber Kirby
# 3804       49687       49683                           Cucumber Kirby
# 3805       49687       49683                           Cucumber Kirby
#
#       aisle_id  department_id  prices  order_id  user_id eval_set  \
# 0            3             19     1.9      2510     4297    prior
# 1          121             14    12.2     10142     4604    prior
# 2           83              4    14.3      1425     2593    prior
# 3           83              4    14.3      1915     4631    prior
# 4           83              4    14.3      1375     5801    prior
# ...        ...            ...     ...       ...      ...      ...
# 3801        83              4    13.2      2803     4282    prior
# 3802        83              4    13.2      9414     4588    prior
# 3803        83              4    13.2      4604     4789    prior
# 3804        83              4    13.2      6088     5321    prior
# 3805        83              4    13.2      7981     5610    prior
#
#       order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0               10          4                 12                     6.0
# 1                5          1                 12                     8.0
# 2                4          1                 14                     7.0
# 3               29          6                 20                     7.0
# 4               16          1                 17                     6.0
# ...            ...        ...                ...                     ...
# 3801            12          3                 17                     7.0
# 3802             5          6                 20                     1.0
# 3803            24          0                 19                     6.0
# 3804            12          0                 15                    12.0
# 3805             5          6                 14                     2.0
#
#       add_to_cart_order  reordered _merge
# 0                    18          1   both
# 1                     7          1   both
# 2                     7          1   both
# 3                     5          1   both
# 4                    10          0   both
# ...                 ...        ...    ...
# 3801                  4          1   both
# 3802                  6          1   both
# 3803                  1          0   both
# 3804                  1          1   both
# 3805                  4          1   both
#
# [3806 rows x 16 columns]

# %% [markdown]
# ### 4. Confirm the results of the merge using the merge flag

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          3806
# left_only        0
# right_only       0
# Name: count, dtype: int64

# %%
# The resulting dataframe (after the merge) has 3806 rows (due to the heavy deletion resulting from aforementioned problem)

# %% [markdown]
# ### 5. Export the newly created dataframe in a suitable format

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged.pkl'))
