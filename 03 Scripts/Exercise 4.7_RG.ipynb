# %% [markdown]
# # 4.7 Deriving New Variables
#
# ### This script contains the following points:
# ####  1. Importing data
# ####  2. If-Statements with User-Defined Functions
# ####  3. If-Statements with the loc() Function
# ####  4. If-Statements with For-Loops
# ####  5. Task

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1. Importing data

# %%
path = r'/Users/rachelgrigiac/Documents/CareerFoundry/Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
# Create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.head()
# Out:
#    order_id  user_id  user_order_number  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2398795        1                  2                   3
# 2    473747        1                  3                   3
# 3   2254736        1                  4                   4
# 4    431534        1                  5                   4
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True         196
# 1                  7                    15.0        False         196
# 2                 12                    21.0        False         196
# 3                  7                    29.0        False         196
# 4                 15                    28.0        False         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          0         Soda        77              7     9.0
# ...

# %% [markdown]
# ## 2. If-Statements with User-Defined Functions

# %%
# Define a function

def price_label (row):
    if row ['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return 'Not enough data'

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/y9/8n80fmjn4t70621k4d0spkzh0000gn/T/ipykernel_1776/93659844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## 3. If-Statements with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/y9/8n80fmjn4t70621k4d0spkzh0000gn/T/ipykernel_1776/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid range product    756450
# Low range product    243550
# Name: count, dtype: int64

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid range product    756450
# Low range product    243550
# Name: count, dtype: int64

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid range product     21860860
# Low range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# ## 4. If-Statements with For-Loops

# %%
for x in range(30, 45):
   print('My age is %d' % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
# Which day most orders take place
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge['orders_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Task

# %% [markdown]
# #### 2.

# %% [markdown]
# I'm using the loc() function to create the labels.

# %%
# Create the 'Busiest Days' label
ords_prods_merge.loc[ords_prods_merge['orders_day_of_week'].isin([0, 1]), 'busiest_days'] = 'Busiest Days'

# %%
# Create the 'Slowest Days' label
ords_prods_merge.loc[ords_prods_merge['orders_day_of_week'].isin([3, 4]), 'busiest_days'] = 'Slowest Days'

# %%
# Create the 'Regularly busy' label
ords_prods_merge.loc[ords_prods_merge['orders_day_of_week'].isin([2, 5, 6]), 'busiest_days'] = 'Regularly busy'

# %% [markdown]
# #### 3.

# %%
# Check values of busiest_days
ords_prods_merge['busiest_days'].value_counts()
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest Days      11864412
# Slowest Days       7624336
# Name: count, dtype: int64

# %%
ords_prods_merge['busiest_day'].shape == ords_prods_merge['busiest_days'].shape
# Out:
# True

# %% [markdown]
# Both of the columns have the same count.
# This grouping makes more sense as it distributes the values more evenly.

# %% [markdown]
# #### 4.

# %%
# Identify the column to be used for this task
ords_prods_merge.head()
# Out:
#    order_id  user_id  user_order_number  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2398795        1                  2                   3
# 2    473747        1                  3                   3
# 3   2254736        1                  4                   4
# 4    431534        1                  5                   4
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True         196
# 1                  7                    15.0        False         196
# 2                 12                    21.0        False         196
# 3                  7                    29.0        False         196
# 4                 15                    28.0        False         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          0         Soda        77              7     9.0
# ...

# %%
ords_prods_merge['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
#Index the value counts to group the values together more easily
value_counts_df = ords_prods_merge['order_hour_of_day'].value_counts().reset_index()

# %%
value_counts_df
# Out:
#     order_hour_of_day    count
# 0                  10  2761760
# 1                  11  2736140
# 2                  14  2689136
# 3                  15  2662144
# 4                  13  2660954
# 5                  12  2618532
# 6                  16  2535202
# 7                   9  2454203
# 8                  17  2087654
# 9                   8  1718118
# 10                 18  1636502
# 11                 19  1258305
# 12                 20   976156
# 13                  7   891054
# 14                 21   795637
# 15                 22   634225
# 16                 23   402316
# 17                  6   290493
# 18                  0   218769
# 19                  1   115700
# 20                  5    87961
# 21                  2    69375
# 22                  4    53242
# 23                  3    51281

# %% [markdown]
# I am going to group the top 8 hours as 'Most orders', then the next 8 hours as 'Average orders', and finally, the last 8 hours as 'Fewest orders'. I will use the loc() function as it takes less time to execute.

# %%
# Create the 'Most orders' label
ords_prods_merge.loc[ords_prods_merge['order_hour_of_day'].isin([10, 11, 14, 15, 13, 12, 16, 9]), 'busiest_period_of_day'] = 'Most orders'

# %%
# Create the 'Average orders' label
ords_prods_merge.loc[ords_prods_merge['order_hour_of_day'].isin([17, 8, 18, 19, 20, 7, 21, 22]), 'busiest_period_of_day'] = 'Average orders'

# %%
# Create the 'Fewest orders' label
ords_prods_merge.loc[ords_prods_merge['order_hour_of_day'].isin([23, 6, 0, 1, 5, 2, 4, 3]), 'busiest_period_of_day'] = 'Fewest orders'

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# #### 7.

# %%
# Export the dataframe as a pickle file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_derived.pkl'))
